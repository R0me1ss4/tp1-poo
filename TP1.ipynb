# %%
import pandas as pd 
Df=pd.read_csv('C:/Users/admin/Documents/Telecom/M1 RT/TP POO/titanic-passengers.csv', delimiter=';')
Df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
Df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Df.drop('Embarked', axis=1)
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
new_data=Df.drop('SibSp', axis=1)
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 76.7+ KB

# %%
Df.tail(2)
# Out:
#      PassengerId Survived  Pclass  \
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 889      0  349215   7.8958   NaN        S
# 890      0  250655  26.0000   NaN        S

# %%
print(Df['Cabin'].head())
print(Df['Cabin'].head().isnull())
# Out:
# 0      NaN
# 1    F G73
# 2      NaN
# 3      NaN
# 4      B71
# Name: Cabin, dtype: object
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Cabin, dtype: bool

# %%
number_of_elements=len(Df["Cabin"])
print("Number of elements:",number_of_elements)
print(Df["Cabin"].value_counts())
Df["Cabin"].fillna('G6',inplace=True)
Df.tail()
# Out:
# Number of elements: 891
# Cabin
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F33            3
# D              3
#               ..
# C91            1
# D45            1
# F G63          1
# A34            1
# E63            1
# Name: count, Length: 147, dtype: int64
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
# ...

# %%
Df['Age'].fillna(Df['Age'].mean(), inplace=True)

# %%
print(Df["Embarked"].value_counts())
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
Df["Embarked"].fillna('S',inplace=True)

# %%
Df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.countplot(x='Sex', data=Df)
plt.xticks(rotation=-45)
plt.show()

# %%
plt.title("Hist pf ages")
plt.xlabel("Age")
Df['Age'].plot.hist()
# Out:
# <AxesSubplot: title={'center': 'Hist pf ages'}, ylabel='Frequency'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd  
def plot_correlation_map( Df ):
 corr = Df.corr()
 s , ax = plt.subplots( figsize =( 12 , 10 ) )
 cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
 s = sns.heatmap(
 corr,
 cmap = cmap,
 square=True,
 cbar_kws={ 'shrink' : .9 },
 ax=ax,
 annot = True,
 annot_kws = { 'fontsize' : 12 }
 )
plot_correlation_map(Df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 17
#       7  cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
#       8  s = sns.heatmap(
#       9  corr,
#      10  cmap = cmap,
#    (...)
#      15  annot_kws = { 'fontsize' : 12 }
#      16  )
# ---> 17 plot_correlation_map(Df)
#
# Cell In[18], line 5, in plot_correlation_map(Df)
#       4 def plot_correlation_map( Df ):
# ----> 5  corr = Df.corr()
#       6  s , ax = plt.subplots( figsize =( 12 , 10 ) )
#       7  cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
# ...

# %%
def plot_correlation_map( Df ):
 corr = Df.corr(numeric_only=True)
 s , ax = plt.subplots( figsize =( 12 , 10 ) )
 cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
 s = sns.heatmap(
 corr,
 cmap = cmap,
 square=True,
 cbar_kws={ 'shrink' : .9 },
 ax=ax,
 annot = True,
 annot_kws = { 'fontsize' : 12 }
 )
plot_correlation_map(Df)
